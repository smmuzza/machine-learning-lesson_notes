# %% [markdown]
# # Actror Critic Methods
#
# * Value based methods
# * Policy based methods
#
# What is we kept track of state or state action values. Enter actor critic methods.
#
# ## A better score function
#
# Need a better score function that can be computed online and is not dependent on an entire episode being played out.
#
# Replace episode return G with the action value of the current state and action Q.
#
# We can use a temporal difference method of iteratively update the action values, does not need an entire episode to play out.
#
# ![ABetterScoreFunction.png](attachment:ABetterScoreFunction.png)
#
# ## Two function approximators (actor and critic)
#
# Apply q learning to update the corresponding action values
#
# ![qLearn2FuncApprox.png](attachment:qLearn2FuncApprox.png)
#
# We can frame this as the actor pi, and the critic q
#
# ![actorPolicyCriticEval.png](attachment:actorPolicyCriticEval.png)
#
# This iterative process can be described as follows
#
# ![actorCriticIteration.png](attachment:actorCriticIteration.png)

# %% [markdown]
# ## Advantage Function
#
# ![policyGrad.png](attachment:policyGrad.png)
#
# The mean is the expected value of Qhat, so the expected value is the mean of the state.
#
# We can subtract away this mean away from each value, and subtract it from the score function, our new score function, the advantage function, should hover around zero since we have subtracted away the mean.
#
# ![subtractMeanAdv.png](attachment:subtractMeanAdv.png)
#
# ![advFunc.png](attachment:advFunc.png)
#
# ## Actor-Critic with Advantage
#
# The TD error delta is a good estimator of the advantage function.
#
# ![actorCriticWithAdv.png](attachment:actorCriticWithAdv.png)
